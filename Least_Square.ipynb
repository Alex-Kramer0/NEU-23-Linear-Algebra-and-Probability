# %% [markdown]
# <a href="https://colab.research.google.com/github/Alex-Kramer0/DS5020/blob/main/Least_Square.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Alex Kramer
# Homework 3
# Part A

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# reading data
data = pd.read_csv('Real estate.csv')
print(data.shape)
print(data.head())

# x = house age
# y = price 
x = data['X2 house age'].values
y = data['Y house price of unit area'].values

# create matrix A
a = ''
for i in range(0, len(x)):
  if i == 0:
    a += '1 ' + str(x[i])
  else:
    a += '; ' + '1 ' + str(x[i])
  # creates a

matrix_a = np.matrix(a)

# create matrix b -- predicted price -- 1D array
b = ''
for e in range(0, len(y)):
  if e == 0:
    b += str(y[e])
  else:
    b += '; ' + str(y[e])

matrix_b = np.matrix(b)

# get A^t (A transpose)
a_transpose = matrix_a.transpose()

# multiply A^t*A (A Transpose times A)
ata = np.matmul(a_transpose, matrix_a)

# multiply A^t*B (A transpose times matrix b)
atb = np.matmul(a_transpose, matrix_b)

# get inverse of ata 
i_ata = ata.getI()

# multply inverse of ata by atb
x_hat = np.matmul(i_ata, atb)

c = float(x_hat[0]) # y-intercept

d = float(x_hat[1]) # slope
print('Coefficents: ')
print('C: ', c, 'D: ', d)
# plot values and regression line
max_x = np.max(x)
min_x = np.min(x)

# calculate line values x and y 
x_value = np.linspace(min_x, max_x, 1000)
y_value = c + d * x_value

# plot line
plt.plot(x_value, y_value, color='#58b970', label='Regression Line')

# plot scatter points
plt.scatter(x, y, c='#ef5423', label='Scatter Plot')

plt.xlabel('House Age')
plt.ylabel('House Price of Unit Area')
plt.legend()
plt.show()
# Out:
# (414, 8)
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %% [markdown]
# Part B:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# reading data
data = pd.read_csv('Real estate.csv')
print(data.shape)
print(data.head())

# x = house age
# y = price 
x = data['X3 distance to the nearest MRT station'].values
y = data['Y house price of unit area'].values

# create matrix A
a = ''
for i in range(0, len(x)):
  if i == 0:
    a += '1 ' + str(x[i])
  else:
    a += '; ' + '1 ' + str(x[i])
  # creates a

matrix_a = np.matrix(a)

# create matrix b -- predicted price -- 1D array
b = ''
for e in range(0, len(y)):
  if e == 0:
    b += str(y[e])
  else:
    b += '; ' + str(y[e])

matrix_b = np.matrix(b)

# get A^t (A transpose)
a_transpose = matrix_a.transpose()

# multiply A^t*A (A Transpose times A)
ata = np.matmul(a_transpose, matrix_a)

# multiply A^t*B (A transpose times matrix b)
atb = np.matmul(a_transpose, matrix_b)

# get inverse of ata 
i_ata = ata.getI()

# multply inverse of ata by atb
x_hat = np.matmul(i_ata, atb)

c = float(x_hat[0]) # y-intercept

d = float(x_hat[1]) # slope
print('Coefficents: ')
print('C: ', c, 'D: ', d)
# plot values and regression line
max_x = np.max(x)
min_x = np.min(x)

# calculate line values x and y 
x_value = np.linspace(min_x, max_x, 1000)
y_value = c + d * x_value

# plot line
plt.plot(x_value, y_value, color='#58b970', label='Regression Line')

# plot scatter points
plt.scatter(x, y, c='#ef5423', label='Scatter Plot')

plt.xlabel('Distance to the nearest MRT station')
plt.ylabel('House Price of Unit Area')
plt.legend()
plt.show()
# Out:
# (414, 8)
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %% [markdown]
# Part B: Section 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
# %matplotlib inline

data = pd.read_csv('Real estate.csv')
print(data.shape)
print(data.head())

x = data['X2 house age'].values
y = data['X3 distance to the nearest MRT station'].values
z = data['Y house price of unit area'].values

d_age = -0.25148841908534525
d_mrt = -0.00726205161814944

c_age = 42.43469704626287 #x c
c_mrt = 45.851427057774956 #y c

avg_age = np.mean(x)
avg_mrt = np.mean(y)
avg_price = np.mean(z)
point = (avg_age, avg_mrt, avg_price)

zz = avg_price + d_age * (x - avg_age) + d_mrt * (y - avg_mrt)

max_x = np.max(x)
min_x = np.min(x)

min_y = np.min(y)
max_y = np.max(y)


x_value = np.linspace(min_x, max_x, 1000)
y_value = np.linspace(min_y, max_y, 1000)

xx, yy = np.meshgrid(x_value, y_value)
#zz = (c_age * xx ) + (c_mrt * yy) + e
fig = plt.figure()

ax =fig.add_subplot(projection='3d')
ax.contour3D(xx, yy, zz, 50)
ax.scatter(x, y, z)

'''
# plot line
plt.plot(x_value, y_value, color='#58b970', label='Regression Line')

# plot scatter points
plt.scatter(x, y, c='#ef5423', label='Scatter Plot')

plt.xlabel('House Age')
plt.ylabel('Distance to MRT Station')
plt.legend()
plt.show()



fig = plt.figure()

ax = fig.gca(projection='3d')

ax.plot_surface(x_value, y_value, z)

plt.show()
'''
# Out:
# (414, 8)
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...
